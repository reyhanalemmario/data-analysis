# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np

# %%
data = pd.read_csv('ppf.csv')
data2 = data.drop(columns = 'dust')
data2.head()
data2.dropna()
# Out:
#         year      temp         co2
# 0      -2342 -1.210000  284.700000
# 1      -2374 -1.440000  284.303333
# 2      -2418 -0.730000  283.906667
# 3      -2460 -0.630000  283.510000
# 4      -2501  0.300000  283.113333
# 5      -2542 -0.270000  282.716667
# 6      -2585 -1.360000  282.320000
# 7      -2628 -0.170000  281.923333
# 8      -2670 -0.020000  281.526667
# 9      -2713 -1.190000  281.130000
# 10     -2760 -1.970000  280.733333
# 11     -2805 -0.610000  280.336667
# 12     -2847  0.580000  279.940000
# 13     -2889 -0.380000  279.543333
# 14     -2934 -1.340000  279.146667
# 15     -2980 -1.410000  278.750000
# 16     -3026 -0.730000  278.353333
# 17     -3070 -0.250000  277.956667
# 18     -3114 -0.530000  277.560000
# 19     -3158 -0.080000  277.163333
# 20     -3201  0.150000  276.766667
# 21     -3245 -0.430000  276.370000
# 22     -3289 -0.610000  275.973333
# 23     -3334 -0.300000  275.576667
# 24     -3379 -0.130000  275.180000
# 25     -3422  0.220000  274.783333
# 26     -3466  0.170000  274.386667
# 27     -3511 -0.910000  273.990000
# 28     -3558 -0.900000  273.593333
# 29     -3603  0.300000  273.196667
# ...      ...       ...         ...
# 3750 -406441  0.310000  280.075000
# 3751 -406957  0.490000  280.262500
# 3752 -407469  0.710000  280.450000
# 3753 -407977  0.850000  280.637500
# 3754 -408485  0.940000  280.825000
# 3755 -408992  1.120000  281.012500
# 3756 -409022  1.173333  281.200000
# 3757 -409022  1.226667  283.700000
# 3758 -409496  1.280000  282.466667
# 3759 -409995  1.640000  281.233333
# 3760 -410200  1.885000  280.000000
# 3761 -410483  2.130000  278.766667
# 3762 -410683  1.843333  277.533333
# 3763 -410831  1.556667  276.300000
# 3764 -410979  1.270000  277.614286
# 3765 -411492  1.340000  278.928571
# 3766 -412009  1.230000  280.242857
# 3767 -412533  1.150000  281.557143
# 3768 -413062  1.080000  282.871429
# 3769 -413601  0.800000  284.185714
# 3770 -414085  0.825000  285.500000
# 3771 -414147  0.850000  285.850000
# 3772 -414692  1.070000  286.200000
# 3773 -415235  1.160000  286.550000
# 3774 -415434  1.145000  286.900000
# 3775 -415781  1.130000  285.040000
# 3776 -416327  1.320000  283.180000
# 3777 -416872  1.360000  281.320000
# 3778 -417095  1.383333  279.460000
# 3779 -417160  1.406667  277.600000
#
# [3780 rows x 3 columns]

# %%
# plt.figure(figsize=(15,10))
# sns.lineplot(x=data2['year'], y=data['temp'])
# sns.pointplot(x=data2['year'], y=data['co2'])
fig, ax = plt.subplots(figsize=(15,10))

sns.lineplot(x='year', y='temp', data=data2, ax=ax, color = 'blue')
plt.ylabel('Suhu', fontsize = 16, color = 'blue')
plt.xlabel('Tahun Sebelum Sekarang', fontsize = 18)
ax2 = ax.twinx()
sns.lineplot(x='year', y='co2', data=data2, ax=ax2, color='r')
plt.ylabel('Konsentrasi CO2',fontsize = 18, color = 'r')
plt.title("Grafik Suhu dan Konsentrasi CO2 pada Waktu Lampau di Antartika", fontsize = 20)
plt.xlabel('Tahun Sebelum Sekarang', fontsize = 16)
#plt.savefig('Grafik Suhu dan Konsentrasi CO2 pada Waktu Lampau di Antartika.png')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='co2', y='temp', data=data2, color = 'g')
sns.regplot(x='co2', y='temp', data=data2, color='g')
plt.xlabel('Konsentrasi CO2', fontsize = 18)
plt.ylabel('Suhu', fontsize = 18)
plt.title('Korelasi antara Konsentrasi CO2 dengan Suhu di Antartika', fontsize = 20)
plt.savefig('Korelasi antara Konsentrasi CO2 dengan Suhu di Antartika.png')
plt.show()

# %%
data3 = data.drop(columns = 'co2')
data3.head()
data3.dropna()
# Out:
#         year      temp      dust
# 51     -4509  1.130000  0.025000
# 52     -4552  0.880000  0.018000
# 53     -4596  0.200000  0.017000
# 54     -4642 -0.330000  0.016000
# 55     -4690 -0.880000  0.015000
# 56     -4739 -0.580000  0.016500
# 57     -4786  0.250000  0.018000
# 58     -4831  0.000000  0.019500
# 59     -4880 -1.140000  0.021000
# 60     -4929 -0.660000  0.022500
# 61     -4977 -0.360000  0.024000
# 62     -5025 -0.660000  0.025500
# 63     -5072  0.130000  0.027000
# 64     -5118  0.180000  0.028500
# 65     -5165 -0.380000  0.030000
# 66     -5212 -0.220000  0.031500
# 67     -5259  0.280000  0.033000
# 68     -5305  0.100000  0.032444
# 69     -5351  0.080000  0.031889
# 70     -5397  0.500000  0.031333
# 71     -5442  0.500000  0.030778
# 72     -5488  0.200000  0.030222
# 73     -5534  0.020000  0.029667
# 74     -5581  0.080000  0.029111
# 75     -5627  0.030000  0.028556
# 76     -5674 -0.060000  0.028000
# 77     -5721 -0.150000  0.027167
# 78     -5769 -0.250000  0.026333
# 79     -5816 -0.220000  0.025500
# 80     -5863  0.150000  0.024667
# ...      ...       ...       ...
# 3760 -410200  1.885000  0.018000
# 3761 -410483  2.130000  0.015000
# 3762 -410683  1.843333  0.012000
# 3763 -410831  1.556667  0.012063
# 3764 -410979  1.270000  0.012125
# 3765 -411492  1.340000  0.012188
# 3766 -412009  1.230000  0.012250
# 3767 -412533  1.150000  0.012313
# 3768 -413062  1.080000  0.012375
# 3769 -413601  0.800000  0.012438
# 3770 -414085  0.825000  0.012500
# 3771 -414147  0.850000  0.012563
# 3772 -414692  1.070000  0.012625
# 3773 -415235  1.160000  0.012688
# 3774 -415434  1.145000  0.012750
# 3775 -415781  1.130000  0.012812
# 3776 -416327  1.320000  0.012875
# 3777 -416872  1.360000  0.012937
# 3778 -417095  1.383333  0.013000
# 3779 -417160  1.406667  0.013250
# 3780 -417419  1.430000  0.013500
# 3781 -417969  1.400000  0.013750
# 3782 -418526  1.270000  0.014000
# 3783 -419095  0.940000  0.014250
# 3784 -419682  0.510000  0.014500
# 3785 -420281  0.540000  0.014750
# 3786 -420527  0.430000  0.015000
# 3787 -420888  0.320000  0.014000
# 3788 -421507  0.150000  0.013000
# 3789 -421761  0.115000  0.012000
#
# [3739 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.lineplot(x='year', y='temp', data=data3, ax=ax, color = 'blue')
plt.ylabel('Suhu', fontsize = 16, color = 'blue')
plt.xlabel('Tahun Sebelum Sekarang', fontsize = 18)
ax.set_ylim([-10,16])
ax2 = ax.twinx()
sns.lineplot(x='year', y='dust', data=data3, ax=ax2, color='r')
plt.ylabel('Dust PPM',fontsize = 18, color = 'r')
plt.title("Grafik Suhu dan Dust PPM pada Waktu Lampau di Antartika", fontsize = 20)
plt.xlabel('Tahun Sebelum Sekarang', fontsize = 16)
ax2.set_ylim([-1,1.8])
#plt.savefig('Grafik Suhu dan Dust PPM pada Waktu Lampau di Antartika.png')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(x='dust', y='temp', data=data3, color = 'g')
sns.regplot(x='dust', y='temp', data=data3, color='g', logx = True)
plt.xlabel('Dust PPM', fontsize = 18)
plt.ylabel('Suhu', fontsize = 18)
plt.title('Korelasi antara Dust PPM dengan Suhu di Antartika', fontsize = 20)
plt.savefig('Korelasi antara Dust PPM dengan Suhu di Antartika.png')
plt.show()
# Out:
# C:\Users\Reyhan\Anaconda3\lib\site-packages\seaborn\regression.py:279: RuntimeWarning: invalid value encountered in log
#   grid = np.c_[np.ones(len(grid)), np.log(grid)]

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go

# Scienti
# Out:
# C:\Users\Reyhan\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:441: DeprecationWarning:
#
# plotly.graph_objs.Marker is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Marker
#   - plotly.graph_objs.histogram.selected.Marker
#   - etc.
#
#
# C:\Users\Reyhan\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:149: DeprecationWarning:
#
# plotly.graph_objs.Annotation is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Annotation
#   - plotly.graph_objs.layout.scene.Annotation
#
#
# C:\Users\Reyhan\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:550: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# C:\Users\Reyhan\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:578: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-8-d01cb44e0e3d> in <module>
#      53 fig = go.Figure(data=data, layout=layout)
#      54
# ---> 55 py.plot(fig, filename='Exponential-Fit-in-python')
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     278             filename=grid_filename,
#     279             world_readable=payload["world_readable"],
# --> 280             auto_open=False,
#     281         )
#     282
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in _create_or_overwrite_grid(data, max_retries)
#    1548     # Create file
#    1549     try:
# -> 1550         res = api_module.create(data)
#    1551     except exceptions.PlotlyRequestError as e:
#    1552         if max_retries > 0 and "already exists" in e.message:
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\grids.py in create(body)
#      16     """
#      17     url = build_url(RESOURCE)
# ---> 18     return request("post", url, json=body)
#      19
#      20
#
# ~\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\utils.py in request(method, url, **kwargs)
#     178         content = response.content if response else "No content"
#     179         raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180     validate_response(response)
#     181     return response
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\utils.py in validate_response(response)
#      80         message = content if content else "No Content"
#      81
# ---> 82     raise exceptions.PlotlyRequestError(message, status_code, content)
#      83
#      84
#
# PlotlyRequestError: Authentication credentials were not provided.

# %%
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-9-c0efa72d0e4a> in <module>
#       3 scatter = fig.add_trace(go.Scatter(y=[2, 3, 1])).data[-1]
#       4 scatter.marker.size = 20
# ----> 5 py.plot(fig)
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     278             filename=grid_filename,
#     279             world_readable=payload["world_readable"],
# --> 280             auto_open=False,
#     281         )
#     282
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in _create_or_overwrite_grid(data, max_retries)
#    1548     # Create file
#    1549     try:
# -> 1550         res = api_module.create(data)
#    1551     except exceptions.PlotlyRequestError as e:
#    1552         if max_retries > 0 and "already exists" in e.message:
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\grids.py in create(body)
#      16     """
#      17     url = build_url(RESOURCE)
# ---> 18     return request("post", url, json=body)
#      19
#      20
#
# ~\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\utils.py in request(method, url, **kwargs)
#     178         content = response.content if response else "No content"
#     179         raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180     validate_response(response)
#     181     return response
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v2\utils.py in validate_response(response)
#      80         message = content if content else "No Content"
#      81
# ---> 82     raise exceptions.PlotlyRequestError(message, status_code, content)
#      83
#      84
#
# PlotlyRequestError: Authentication credentials were not provided.
